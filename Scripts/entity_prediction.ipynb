# %%
from operator import index
import os
from pathlib import Path
import pandas as pd
from collections import Counter

import spacy
from spacy import displacy
from spacy.tokens import DocBin
import json
from datetime import datetime
from tqdm import tqdm
import re
import html
import nltk
lemma = nltk.wordnet.WordNetLemmatizer()
import hunspell
hobj = hunspell.HunSpell('/usr/share/hunspell/en_US.dic', '/usr/share/hunspell/en_US.aff')
from krovetzstemmer import Stemmer as krovetzStemmer
krovetz = krovetzStemmer()
spacynlp = spacy.load("en_core_web_sm")
spacylemma = lambda x: " ".join([token.lemma_ for token in spacynlp(x)])
symbol_free = lambda x: " ".join(x.lower().translate({ord(c):" " for c in "!@#$%^&*()[]{};:,./<>?\|`~-=_+–"}).split())

# specify the GPU to use
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
inputPath = './NER/'
outPath = './NER_AnnoSuite/'
modelPath = "./NER_AnnoSuite/model_expand_all/model-best"

# %%
colors = {
        "D-spi": "lightblue",
        "D-rac": "lightblue",
        "D-gen": "lightblue",
        "D-sxo": "lightblue",
        "D-soc": "lightblue",
        "D-age": "lightblue",
        "B-ces": "#b9db57",
        "B-tme": "#b9db57",
        "B-use": "#b9db57",
        "B-int": "#b9db57",
        "B-pcp": "#b9db57",
        "B-hlt": "#b9db57",
        "B-exp": "#b9db57",
        "B-prv": "#b9db57",
        "B-stm": "#b9db57",
        "M-mth": "#57db94",
        "M-sts": "#57db94",
        "M-dat": "#57db94",
        "C-con": "#5784db",
        "C-chm": "#5784db",
        "C-flv": "#5784db",
        "C-dgn": "#5784db",
        "C-oth": "#5784db",
        "T-etc": "#c957db",
        "T-com": "#c957db",
        "T-oth": "#c957db",
        "T-mkt": "#c957db",
        "P-reg": "lightyellow",
        "P-bod": "lightyellow",
        "P-lic": "lightyellow",
        "P-mkt": "lightyellow",
        "P-red": "lightyellow",
        "P-trt": "lightyellow",
        "P-lbl": "lightyellow",
        "R-rel": "#62d835",
        "L-loc": "#ff2600",
    }

options = {
    "ents": [
        "D-spi",
        "D-rac",
        "D-gen",
        "D-sxo",
        "D-soc",
        "D-age",
        "B-ces",
        "B-tme",
        "B-use",
        "B-int",
        "B-pcp",
        "B-hlt",
        "B-exp",
        "B-prv",
        "B-stm",
        "M-mth",
        "M-sts",
        "M-dat",
        "C-con",
        "C-chm",
        "C-flv",
        "C-dgn",
        "C-oth",
        "T-etc",
        "T-com",
        "T-oth",
        "T-mkt",
        "P-reg",
        "P-bod",
        "P-lic",
        "P-mkt",
        "P-red",
        "P-trt",
        "P-lbl",
        "R-rel",
        "L-loc",
    ],
    "colors": colors,
}

# %%
def EntityPredictDisplay(test_txt, display=True):
    # pass our test instance into the trained pipeline
    doc = nlp_output(test_txt)

    # customize the label colors
    colors = {
        "D-spi": "lightblue",
        "D-rac": "lightblue",
        "D-gen": "lightblue",
        "D-sxo": "lightblue",
        "D-soc": "lightblue",
        "D-age": "lightblue",
        "B-ces": "#b9db57",
        "B-tme": "#b9db57",
        "B-use": "#b9db57",
        "B-int": "#b9db57",
        "B-pcp": "#b9db57",
        "B-hlt": "#b9db57",
        "B-exp": "#b9db57",
        "B-prv": "#b9db57",
        "B-stm": "#b9db57",
        "M-mth": "#57db94",
        "M-sts": "#57db94",
        "M-dat": "#57db94",
        "C-con": "#5784db",
        "C-chm": "#5784db",
        "C-flv": "#5784db",
        "C-dgn": "#5784db",
        "C-oth": "#5784db",
        "T-etc": "#c957db",
        "T-com": "#c957db",
        "T-oth": "#c957db",
        "T-mkt": "#c957db",
        "P-reg": "lightyellow",
        "P-bod": "lightyellow",
        "P-lic": "lightyellow",
        "P-mkt": "lightyellow",
        "P-red": "lightyellow",
        "P-trt": "lightyellow",
        "P-lbl": "lightyellow",
        "R-rel": "#62d835",
        "L-loc": "#ff2600",
    }

    options = {
        "ents": [
            "D-spi",
            "D-rac",
            "D-gen",
            "D-sxo",
            "D-soc",
            "D-age",
            "B-ces",
            "B-tme",
            "B-use",
            "B-int",
            "B-pcp",
            "B-hlt",
            "B-exp",
            "B-prv",
            "B-stm",
            "M-mth",
            "M-sts",
            "M-dat",
            "C-con",
            "C-chm",
            "C-flv",
            "C-dgn",
            "C-oth",
            "T-etc",
            "T-com",
            "T-oth",
            "T-mkt",
            "P-reg",
            "P-bod",
            "P-lic",
            "P-mkt",
            "P-red",
            "P-trt",
            "P-lbl",
            "R-rel",
            "L-loc",
        ],
        "colors": colors,
    }

    # visualize the identified entities
    # svg = displacy.render(doc, style="dep", options=options, jupyter=True)
    if display:
        displacy.render(doc, style="ent", options=options)
    return doc

# %%
nlp_output = spacy.load(modelPath)
# Out:
# /home/nbook/anaconda3/envs/tobacco/lib/python3.9/site-packages/spacy/util.py:837: UserWarning: [W095] Model 'en_pipeline' (0.0.0) was trained with spaCy v3.2 and may not be 100% compatible with the current version (3.3.2). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
df_test = pd.read_csv(inputPath + "testDataset.csv", encoding="utf8").fillna("")
print(len(df_test))
# Out:
# 300

# %%
# sheet_id = "1L30o1enMWRW---ILpZ5_4UzdygQb6tbgFUVobAJ0TI0"
# sheet_name = "Sheet1"
# url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
# df = pd.read_csv(url)
df = pd.read_csv('/home/nbook/Projects/Tobacco/LGBTQ/lgbtq_articles_clean.csv')
# df

# %%
num = 18#6
record = df.loc[num,]
# txt = " ".join(txt.split())  # to remove extra space (2 or more spaces)
txt = record["Title"] + '. ' + record["Abstract"] #+ str(record["Highlights"])
# txt = (
#     txt.replace(", ", " , ")
#     .replace(". ", " . ")
#     .replace("? ", " ? ")
#     .replace("(", "( ")
#     .replace(")", " )")
#     .replace("/", " / ")
# )
txt = txt.replace("+", " ")
txt = " ".join(txt.split())  # to remove extra space (2 or more spaces)

ner = EntityPredictDisplay(txt)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Sexual and
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gender Minority
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">D-gen</span>
# </mark>
#  College
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Students
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">D-age</span>
# </mark>
#  and
# <mark class="entity" style="background: #b9db57; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tobacco Use
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-use</span>
# </mark>
#  in
# <mark class="entity" style="background: #ff2600; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Texas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">L-loc</span>
# </mark>
# . Introduction Most research regarding sexual and
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gender minority
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">D-gen</span>
# </mark>
#  (SGM) populations is limited to examination of
# <mark class="entity" style="background: #c957db; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cigarette
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">T-com</span>
# </mark>
#  or general
# <mark class="entity" style="background: #b9db57; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tobacco use
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-use</span>
# </mark>
#  or does not examine heterogeneity across SGM groups other than
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lesbian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">D-sxo</span>
# </mark>
#  or
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gay
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">D-sxo</span>
# </mark>
#  and
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bisexual
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">D-sxo</span>
# </mark>
#  individuals. This study examined differences in
# <mark class="entity" style="background: #57db94; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the odds of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">M-sts</span>
# </mark>
#
# <mark class="entity" style="background: #b9db57; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     current use
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-use</span>
# </mark>
#  and
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     age
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">D-age</span>
# </mark>
#  of
# <mark class="entity" style="background: #b9db57; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     initiation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-use</span>
# </mark>
#  of five tobacco/
# <mark class="entity" style="background: #5784db; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nicotine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">C-chm</span>
# </mark>
#  products among three groups of SGM
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     young adults
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">D-age</span>
# </mark>
#  who self-identified as (1)
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gay
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">D-sxo</span>
# </mark>
#  or
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lesbian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">D-sxo</span>
# </mark>
# , (2)
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bisexual
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">D-sxo</span>
# </mark>
# , and (3)
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     queer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">D-sxo</span>
# </mark>
# ,
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     transgender
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">D-gen</span>
# </mark>
# , or “other,” compared to their
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     heterosexual
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">D-sxo</span>
# </mark>
#  peers. Methods Participants were 4252 college
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     students
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">D-age</span>
# </mark>
#
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     aged
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">D-age</span>
# </mark>
#
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; bor

# %%
a = displacy.render(ner, style="ent", jupyter=False, options=options)

# %%
with open('test.html', 'w') as f:
    f.write(a)

# %%
df_ents = pd.DataFrame(columns=['PaperIdx', 'Conference','Year','Title','PaperType','Link','AuthorNames','AuthorAffiliation', 'Text', 'Entity', 'Start', 'End', 'Label'])
for idx, row in tqdm(df.iterrows(), total=df.shape[0]):
    txt = row["Title"] + '. ' + row["Abstract"] + str(row["Highlights"])
    txt = txt.replace("+", " ")
    txt = " ".join(txt.split())  # to remove extra space (2 or more spaces)
    ner = EntityPredictDisplay(txt, display=False)
    html_out = displacy.render(ner, style="ent", jupyter=False, options=options)
    html_name = f'[{idx}] {" ".join(row["Title"].replace("/", " or ").split(" ")[:5])}'
    with open(f'./NER/LGBTQColoredText/{html_name}.html', 'w') as f:
        f.write(html_out)
    for ent in ner.ents:
        df_ents.loc[df_ents.shape[0]] = {
            'PaperIdx': idx,
            'Conference':row['Conference'], 'Year':row['Year'], 'Title':row['Title'], 'PaperType':row['PaperType'], 'Link':row['Link'], 
            'AuthorNames':row['AuthorNames'], 'AuthorAffiliation':row['AuthorAffiliation'], 
            'Text':txt, 'Entity':ent.text, 'Start':ent.start_char, 'End':ent.end_char, 'Label':ent.label_
        }
# Out:
# 100%|██████████| 33/33 [00:05<00:00,  5.77it/s]

# %%
df_ents.to_csv('/home/nbook/Projects/Tobacco/LGBTQ/lgbtq_articles_clean_ents.csv', index=False)

# %%
with open(inputPath + 'LGBTQDatasetNER.csv', 'w') as f:
    f.writelines('index,named_entities\n')
    for idx, row in tqdm(df.iterrows(), total=len(df)):
        doc = EntityPredictDisplay(f"{row['Abstract']} {row['Highlights']}")
        ents = [(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents]
        f.writelines(str(row['Link']) + ',' + str(ents) + '\n')
# Out:
# 100%|██████████| 68/68 [00:04<00:00, 15.96it/s]

# %%
lookup_set = []
entities_clean = pd.read_csv('/home/nbook/Projects/Tobacco/TobaccoResearch_Meng/NER/TobaccoNamedEntitiesV3.csv')
for e in entities_clean.entities.values:
    lookup_set.extend(e.split(','))
lookup_set = [spacylemma(symbol_free(i)) for i in lookup_set]
lookup_set = list(set(lookup_set))
# for i, w in enumerate(lookup_set):
#     # w_list = w.split(' ')
#     # for j, sub_w in enumerate(w_list):
#     #     if len(hobj.stem(sub_w)) > 0:
#     #         w_list[j] = hobj.stem(sub_w)[0].decode()
#     #     else:
#     #         w_list[j] = lemma.lemmatize(sub_w)
#     # lookup_set[i] = " ".join(w_list)
#     lookup_set[i] = spacylemma(w)

# %%
df = pd.read_csv('/home/nbook/Projects/Tobacco/LGBTQ/lgbtq_articles_clean_ents.csv')
df
# Out:
#       PaperIdx                      Conference  Year  \
# 0            0                 Tobacco Control  2015
# 1            0                 Tobacco Control  2015
# 2            0                 Tobacco Control  2015
# 3            0                 Tobacco Control  2015
# 4            0                 Tobacco Control  2015
# ...        ...                             ...   ...
# 1966        32  Tobacco Prevention & Cessation  2020
# 1967        32  Tobacco Prevention & Cessation  2020
# 1968        32  Tobacco Prevention & Cessation  2020
# 1969        32  Tobacco Prevention & Cessation  2020
# 1970        32  Tobacco Prevention & Cessation  2020
#
#                                                   Title       PaperType  \
# 0     Disadvantaged youth and smoking in mature toba...  Review Article
# 1     Disadvantaged youth and smoking in mature toba...  Review Article
# 2     Disadvantaged youth and smoking in mature toba...  Review Article
# 3     Disadvantaged youth and smoking in mature toba...  Review Article
# 4     Disadvantaged youth and smoking in mature toba...  Review Article
# ...                                                 ...             ...
# 1966  Comparing smoking behavior between female-to-m...  RESEARCH PAPER
# 1967  Comparing smoking behavior between female-to-m...  RESEARCH PAPER
# 1968  Comparing smoking behavior between female-to-m...  RESEARCH PAPER
# 1969  Comparing smoking behavior between female-to-m...  RESEARCH PAPER
# 1970  Comparing smoking behavior between female-to-m...  RESEARCH PAPER
#
#                                                    Link  \
# 0     http://dx.doi.org/10.1136/tobaccocontrol-2014-...
# 1     http://dx.doi.org/10.1136/tobaccocontrol-2014-...
# 2     http://dx.doi.org/10.1136/tobaccocontrol-2014-...
# 3     http://dx.doi.org/10.1136/tobaccocontrol-2014-...
# 4     http://dx.doi.org/10.1136/tobaccocontrol-2014-...
# ...                                                 ...
# 1966              http://dx.doi.org/10.18332/tpc/114513
# 1967              http://dx.doi.org/10.18332/tpc/114513
# 1968              http://dx.doi.org/10.18332/tpc/114513
# 1969              http://dx.doi.org/10.18332/tpc/114513
# 1970              http://dx.doi.org/10.18332/tpc/114513
#
#                                             AuthorNames  \
# 0                         Marita Hefler; Simon Chapman;
# 1                         Marita Hefler; Simon Chapman;
# 2                         Marita Hefler; Simon Chapman;
# 3                         Marita Hefler; Simon Chapman;
# 4                         Marita Hefler; Simon Chapman;
# ...                                                 ...
# 1966  Irene Tamí-Maury; Anushree Sharma; Minxing Che...
# 1967  Irene Tamí-Maury; Anushree Sharma; Minxing Che...
# 1968  Irene Tamí-Maury; Anushree Sharma; Minxing Che...
# 1969  Irene Tamí-Maury; Anushree Sharma; Minxing Che...
# 1970  Irene Tamí-Maury; Anushree Sharma; Minxing Che...
#
#                                       AuthorAffiliation  \
# 0     A27-School of Public Health, University of Syd...
# 1     A27-School of Public Health, University of Syd...
# 2     A27-School of Public Health, University of Syd...
# 3     A27-School of Public Health, University of Syd...
# 4     A27-School of Public Health, University of Syd...
# ...                                                 ...
# 1966  Department of Epidemiology, Human Genetics and...
# 1967  Department of Epidemiology, Human Genetics and...
# 1968  Department of Epidemiology, Human Genetics and...
# 1969  Department of Epidemiology, Human Genetics and...
# 1970  Department of Epidemiology, Human Genetics and...
#
#                                                    Text             Entity  \
# 0     Disadvantaged youth and smoking in mature toba...              youth
# 1     Disadvantaged youth and smoking in mature toba...    tobacco control
# 2     Disadvantaged youth and smoking in mature toba...  systematic review
# 3     Disadvantaged youth and smoking in mature toba...          synthesis
# 4     Disadvantaged youth and smoking in mature toba...        qualitative
# ...                                                 ...                ...
# 1966  Comparing smoking behavior between female-to-m...        transgender
# 1967  Comparing smoking behavior between female-to-m...             adults
# 1968  Comparing smoking behavior between female-to-m...        transgender
# 1969  Comparing smoking behavior between female-to-m...               2015
# 1970  Comparing smoking behavior between female-to-m...            Houston
#
#       Start  End  Label  NewDiscover         BaseEntity
# 0        14   19  D-age         True              youth
# 1        42   57  P-reg         True    tobacco control
# 2        70   87  M-mth         True  systematic review
# 3        92  101  M-mth         True          synthesis
# 4       105  116  M-mth         True        qualitative
# ...     ...  ...    ...          ...                ...
# 1966     69   80  D-gen         True        transgender
# 1967     81   87  D-age         True              adult
# 1968    107  118  D-gen         True        transgender
# 1969    204  208  B-tme        False               2015
# 1970    209  216  L-loc         True            houston
#
# [1971 rows x 15 columns]

# %%
for idx, row in df.iterrows():
    # check if the entity is in the lookup set
    df.loc[idx, 'NewDiscover'] = True if (
            spacylemma(symbol_free(row['Entity']))
            in lookup_set
        ) else False
    df.loc[idx, 'BaseEntity'] = spacylemma(symbol_free(row['Entity']))

# %%
df.loc[df.BaseEntity.isin(['lgbt', 'lgb', 'glbt', 'lgbti', 'lgbtq', 'non lgb', 'non lgbt', 'non lgbtq']), ['Label']] = 'D-sxo'

# %%
df.to_csv('/home/nbook/Projects/Tobacco/LGBTQ/lgbtq_articles_clean_ents.csv', index=False)

# %%
spacylemma(symbol_free('women'))
# Out:
# 'woman'

# %% [markdown]
# # Evaluation

# %%
test_text = pd.read_csv('/home/nbook/Projects/Tobacco/LGBTQ/lgbtq_articles_clean.csv')

# %%
from spacy.scorer import Scorer
def evaluate(ner_model, samples):
    scorer = Scorer(ner_model)
    example = []
    for sample in samples:
        pred = ner_model(sample['text'])
        print(pred, sample['entities'])
        temp_ex = Example.from_dict(pred, {'entities': sample['entities']})
        example.append(temp_ex)
    scores = scorer.score(example)
    
    return scores

evaluate(nlp_output, )

# %% [markdown]
# # -------------------

# %%
df = pd.read_csv('/home/nbook/Projects/Tobacco/LGBTQ/ERCountPerPaper.csv')
df['BaseEntity'] = df['BaseEntity'].apply(lambda x: spacylemma(symbol_free(x)))
df

# %%
df2 = pd.read_csv('/home/nbook/Projects/Tobacco/LGBTQ/LGBTQEntitiesClean.csv')
df2.fillna(method='ffill')
# Out:
#                                        MajorCategory        SubCategory  \
# 0    Tobacco Use Behaviors, Prevalence, and Outcomes  Tobacco Cessation
# 1    Tobacco Use Behaviors, Prevalence, and Outcomes  Tobacco Cessation
# 2    Tobacco Use Behaviors, Prevalence, and Outcomes  Tobacco Cessation
# 3    Tobacco Use Behaviors, Prevalence, and Outcomes  Tobacco Cessation
# 4    Tobacco Use Behaviors, Prevalence, and Outcomes  Tobacco Cessation
# ..                                               ...                ...
# 176                          Tobacco Characteristics           Chemical
# 177                          Tobacco Characteristics             Flavor
# 178                          Tobacco Characteristics             Flavor
# 179                          Tobacco Characteristics             Flavor
# 180                          Tobacco Characteristics             Flavor
#
#       NamedEntityClean                                   NamedEntity  \
# 0    Quitting Behavior  Abstinence, Cessation, Quit, Smoke Cessation
# 1         Quit Attempt                                  Quit Attempt
# 2            Quit Rate                                     Quit Rate
# 3              Relapse                                       Relapse
# 4       Advice to Quit                                Advice to Quit
# ..                 ...                                           ...
# 176           Additive                                      Additive
# 177            Alcohol                                       Alcohol
# 178            Menthol                                       Menthol
# 179        Non-menthol                                   Non-menthol
# 180             Flavor                                        Flavor
#
#      FrequencyByAbstract
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ..                   ...
# 176                  NaN
# 177                  NaN
# 178                  NaN
# 179                  NaN
# 180                  NaN
#
# [181 rows x 5 columns]

# %%
for idx, row in df2.iterrows():
    entities = row['NamedEntity'].split(', ')
    total = 0
    for e in entities:
        base_e = spacylemma(symbol_free(e))
        lookup = df.loc[df.BaseEntity == base_e, 'Frequency'].values
        assert len(lookup) == 1
        total += lookup[0]
    df2.loc[idx, 'FrequencyByAbstract'] = total

# %%
df2['FrequencyByAbstract'] = df2['FrequencyByAbstract'].astype(int)

# %%
df2.to_csv('/home/nbook/Projects/Tobacco/LGBTQ/LGBTQEntitiesClean.csv', index=False)

# %% [markdown]
# # --------------------------

# %%
name_map = {
    'Tobacco Use Behaviors, Prevalence, and Outcomes':'Behavioral',
    'Population Characteristics':'Demographic',
    'Geographic Locations':'Location',
    'Method and Inference':'Method',
    'Tobacco Products':'Product',
    'Relation Statement':'Relation',
    'Tobacco Characteristics':'Tobacco',
    'Policy':'Policy',
}

# %%
clean = pd.read_csv('/home/nbook/Projects/Tobacco/LGBTQ/ERCountPerPaper.csv')
clean = clean.fillna(method='ffill')
# clean['NamedEntity'] = clean['NamedEntity'].apply(lambda x: spacylemma(symbol_free(x)))
raw = pd.read_csv('/home/nbook/Projects/Tobacco/LGBTQ/LGBTQEntities.csv')
raw['BaseEntity'] = raw['BaseEntity'].apply(lambda x: spacylemma(symbol_free(x)))

# %%
for idx, row in clean.iterrows():
    entities = [spacylemma(symbol_free(x)) for x in row.NamedEntity.split(', ')]
    raw_main_cat = name_map[row['MajorCategory']]
    paper_set = []
    for e in entities:
        resulst = raw.loc[(raw.BaseEntity == e) & (raw.MainCat == raw_main_cat), 'PaperIdx'].to_list()
        if len(resulst) == 0:
            resulst = raw.loc[(raw.BaseEntity == e), 'PaperIdx'].to_list()
        paper_set.extend(resulst)
    paper_set = list(set(paper_set))
    clean.loc[idx, 'NewFrequency'] = len(paper_set)
clean['NewFrequency'] = clean['NewFrequency'].astype(int)

# %%
clean.to_csv('/home/nbook/Projects/Tobacco/LGBTQ/ERCountPerPaperMergedNE.csv', index=False)

# %%
row = clean.iloc[59]
row
# Out:
# MajorCategory          Population Characteristics
# SubCategory                            Age Groups
# NamedEntityClean                        ≥16 Years
# NamedEntity                             ≥16 Years
# FrequencyByAbstract                             1
# NewFrequency                                    0
# Name: 59, dtype: object

# %%
raw_main_cat = name_map[row['MajorCategory']]
raw_main_cat
# Out:
# 'Demographic'

# %%
entities = [spacylemma(symbol_free(x)) for x in row.NamedEntity.split(', ')]
entities
# Out:
# ['≥16 year']

# %%
raw.loc[(raw.BaseEntity == entities[0]) & (raw.MainCat == raw_main_cat), 'PaperIdx'].to_list()
# Out:
# []
